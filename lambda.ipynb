# %%
d1={'ronaldo':34,'messi':31,'neymar':25}
d1.clear()

# %%
d1.clear()

# %%
d1={'ronaldo':34,'messi':31,'neymar':25}
# Out:
# {}

# %%
d2={'ronaldo':34,'messi':31,'neymar':25}
d1=d2.copy()
d1
# Out:
# {'ronaldo': 34, 'messi': 31, 'neymar': 25}

# %%
d2.clear()
d1,d2
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
# pop, popitem and del practice practice and practice until you get it to become good programmer.
d2={'ronaldo':34,'messi':31,'neymar':25}
d2.pop()
d2
# Out:
# {'ronaldo': 34, 'messi': 31}

# %%
d1={'a':20, 'b':30, 'c':40}
d2={'a':21, 'b':40, 'c':30}
for i in d2:
    d1[i]+=d2[i]
d1   
d2
# Out:
# {'a': 21, 'b': 40, 'c': 30}

# %%
d2={'a':21, 'b':40, 'c':30}
d2.pop('b')
# Out:
# 40

# %%
d2={'a':21, 'b':40, 'c':30}
d2.popitem()
# Out:
# ('c', 30)

# %%
d2={'a':21, 'b':40, 'c':30}
del d2['a']
d2
# Out:
# {'b': 40, 'c': 30}

# %%
#get method
d2={'a':21, 'b':40, 'c':30}
d2.get('a')
# Out:
# 21

# %%
d1={'ronaldo':34,'messi':31,'neymar':25}
d2=d1.fromkeys('ronaldo')
d2
d1
# Out:
# {'ronaldo': 34, 'messi': 31, 'neymar': 25}

# %%
d3={}.fromkeys([1,2,3],'odd')
d3
# Out:
# {1: 'odd', 2: 'odd', 3: 'odd'}

# %%
d1={}
d1.setdefault('naresh it','data science')
d1.setdefault('science')
d1
# Out:
# {'naresh it': 'data science', 'science': None}

# %%
#another method of creating dic
d1={}
d1['name']=['Naresh']
d1
# Out:
# {'name': ['Naresh']}

# %%
#update() method
d1={'ronaldo':34,'messi':31,'neymar':25}
d2={'a':21, 'b':40, 'c':30}
d1.update(d2)
d1
# Out:
# {'ronaldo': 34, 'messi': 31, 'neymar': 25, 'a': 21, 'b': 40, 'c': 30}

# %%
def add(x):
    summ=x+10
    return(summ)
add(10)
# Out:
# 20

# %%
add=lambda x:x+10
add(20)
# Out:
# 30

# %%
square = lambda x:x*x
square(2)
# Out:
# 4

# %%
cube = lambda x:x*x*x
cube(2)
# Out:
# 8

# %%
add = lambda x,a:x+a
add(12,12)
# Out:
# 24

# %%
#average of 3 numbers using lambda
average= lambda x,y,z=6:(x+y+z)/3
average(4,5)
# Out:
# 5.0

# %%
l1=[]
def greater(a,b):
    if a>b:
        l1.append(a)
    else:
        l1.append(b)
greater(3,4)
l1
l1
# Out:
# [4]

# %%
#using lambda function
greater= lambda a,b:a if a>b else b 
greater(2,4)
# Out:
# 4

# %%
list1=['ronaldo','messi','neymar']
list2=[]
for i in list1:
    list2.append(i.capitalize())
list2
# Out:
# ['Ronaldo', 'Messi', 'Neymar']

# %%
lambda i:i.capitalize(), list1
map(lambda i:i.capitalize(), list1)
list(map(lambda i:i.capitalize(), list1))
# Out:
# ['Ronaldo', 'Messi', 'Neymar']

# %%
list1=[1,2,3,4,5]

# %%
list1=[1,2,3,4,5]
print(list(map(lambda i:i*i, list1)))
# Out:
# [1, 4, 9, 16, 25]

# %%
#using normal list
list1=[]
list2=[1,2,3,4,5]
for i in list2:
    list1.append(i*i)
list1
# Out:
# [1, 4, 9, 16, 25]

# %%
list1=[1,2,3]
list2=[11,22,33]
list(map(lambda i,j:i+j, list1,list2))
# Out:
# [12, 24, 36]

# %%
list1=['h#d','mumb#i','chennai']
[ i for i in list1 if '#' in i]
# Out:
# ['h#d', 'mumb#i']

# %%
list1=['h#d','mumb#i','chennai']
c2=list(filter(lambda i: '#' in i, list1))
c2
# Out:
# ['h#d', 'mumb#i']
