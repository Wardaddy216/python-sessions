# %%
def addition():
    n1=10
    n2=30
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition()
# Out:
# the addition of 10 and 30 is 40

# %%
def average():
    n1=eval(input("enter first number"))
    n2=eval(input("enter second number"))
    n3=eval(input("enter third number"))
    aver=(n1+n2+n3)/3
    print("the average of {}, {} and {} is: {}".format(n1,n2,n3,aver))
average()
# Out:
# enter first number 3
# enter second number 4
# enter third number 5
# the average of 3, 4 and 5 is: 4.0

# %%
def add():
    n1=20
    n2=40
    print("addition",n1+n2)
print("mul function starts")
def mul():
    n1=20
    n2=40
    print("multiplication",n1*n2)
print("subtraction function starts")
def sub():
    n1=20
    n2=40
    print("sub",n1-n2)
    print("subtraction is done")
print("anything remains")
print("no")
print("then call the function")
sub()
mul()
add()
# Out:
# mul function starts
# subtraction function starts
# anything remains
# no
# then call the function
# sub -20
# subtraction is done
# multiplication 800
# addition 60

# %%
def average(n1,n2,n3):
    aver=(n1+n2+n3)/3
    print("the average of {}, {} and {} is: {}".format(n1,n2,n3,aver))
average(10,20,30)
# Out:
# the average of 10, 20 and 30 is: 20.0

# %%
import random
def compar(n1):
    n2=random.randint(1,20)
    if n1==n2:
        print("you won")
    else:
        print("you lost beause the number is:",n2)
compar(eval(input("enter a number")))
# Out:
# enter a number 7
# you lost beause the number is: 4

# %%
def calc(salary,taxpercentage):
    total_tax=(salary*taxpercentage)/100
    print("the total tax is:",total_tax)
percentage=10
calc(eval(input("enter your freakin salary")),percentage)
# Out:
# enter your freakin salary 2000000
# the total tax is: 200000.0
