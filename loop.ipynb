# %%
for x in range(10):
    print("the value of x is:",x,end='')
# Out:
# the value of x is: 0the value of x is: 1the value of x is: 2the value of x is: 3the value of x is: 4the value of x is: 5the value of x is: 6the value of x is: 7the value of x is: 8the value of x is: 9

# %%
#second pattern
for x in range(1,10):
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#3rd pattern
for x in range(1,10,2):
    print(x)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
num1=eval(input("enter a number"))
for x in range(1,5):
    print("the square of {} is {}:".format(num1,num1*num1))
# Out:
# enter a number 5
# the square of 5 is 25:
# the square of 5 is 25:
# the square of 5 is 25:
# the square of 5 is 25:

# %%
import random
def square():
    for i in range(5):
        num1=random.randint(1,20)
        print("the square of {} is {}:".format(num1,num1*num1))
square()
# Out:
# the square of 20 is 400:
# the square of 18 is 324:
# the square of 5 is 25:
# the square of 16 is 256:
# the square of 19 is 361:

# %%
import random
random_num=random.randint(1,10)
chances=eval(input("enter the no of chances"))
for i in range(chances):
    num1=eval(input("enter a number"))
    if num1==random_num:
        print("you won")
        break
    if chances-1-i==0:
            print("you lost all the chances and try again after 10 mins")

    else:
        print("you lost")
        print("the no of chances remaining is",chances-1-i)
# Out:
# enter the no of chances 2
# enter a number 4
# you lost
# the no of chances remaining is 1
# enter a number 5
# you lost all the chances and try again after 10 mins
