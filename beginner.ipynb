# %%
number = 100
number
# Out:
# 100

# %%
type(number)
# Out:
# int

# %%
number=106.6
type(number)
# Out:
# float

# %%
0b1111
# Out:
# 15

# %%
10e-6
# Out:
# 1e-05

# %%
sudip="""hello
                  wardell"""
sudip
# Out:
# 'hello\n                  wardell'

# %% [markdown]
# value= False
# value

# %%
value = False 
type(value)
# Out:
# bool

# %%
a=100
b=200
if a>b:
    print ("true")
else: 
    print ("false")
# Out:
# false

# %%
number1 = 3+5j
dir(number1)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  'conjugate',
#  'imag',
#  'real']

# %%
number1.real
# Out:
# 3.0

# %%
number1.imag
# Out:
# 5.0

# %%
number1.conjugate()
# Out:
# (3-5j)

# %%
complex()
# Out:
# 0j
