# %%
list=['A','B']
print(list)
# Out:
# ['A', 'B']

# %%
type(list)
# Out:
# list

# %%
max(list)
# Out:
# 'B'

# %%
list1=['A','B','C','D']
print(list1)
# Out:
# ['A', 'B', 'C', 'D']

# %%
list2=[1,2,3,4]
list2
# Out:
# [1, 2, 3, 4]

# %%
list3=list1+list2
print(list3)
len(list3)
# Out:
# ['A', 'B', 'C', 'D', 1, 2, 3, 4]
# 8

# %%
list3[0],list3[1]
# Out:
# ('A', 'B')

# %%
i=1
for i in range(len(list3)):
    print(list3[i])
# Out:
# A
# B
# C
# D
# 1
# 2
# 3
# 4

# %%
#WAP to find the elements which are having len<3 
list=['Apple','Ball','Cat','Aa','Bb','Cc','Ee']
print(list[0])
for i in list:
    if len(i)<3:
        print(i)
# Out:
# Apple
# Aa
# Bb
# Cc
# Ee

# %%
list2=['App#e','B#ll','C#t','Ab','Cd','Ef']
for i in list2:
    if i=='#':
        print(i)

# %%
list2=['App#e','B#ll','C#t','Ab','Cd','Ef']
for i in list2:
    if '#' in i :
        print(i)
# Out:
# App#e
# B#ll
# C#t

# %%
list1=[1,2,3,['Apple','Ball']]
list1[3][0]
# Out:
# 'Apple'

# %%
list3=[[[['A','B',[[[1,2,3,['Car']]]]]]]]
list3[0][0][0][2][0][0][3]
# Out:
# ['Car']

# %%
# Assistant
# Creating a deeply nested list with multiple levels of nesting
list3=[[[['A','B',[[[1,2,3,['Car']]]]]]]]

# Accessing the element 'Car' through multiple index operations:
# list3[0] - first element of the outermost list
# [0] - first element of the next level
# [0] - first element of the next level
# [2] - third element of the next level (which is [[[1,2,3,['Car']]]])
# [0] - first element of the next level
# [0] - first element of the next level
# [3] - fourth element of the innermost list (which is 'Car')
list3[0][0][0][2][0][0][3]
# Out:
# ['Car']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list1=[1,2,3,4,4]
list2=list1.copy()
list2
# Out:
# [1, 2, 3, 4]

# %%
list2=list2.count(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 list2=list2.count(2)
#
# AttributeError: 'int' object has no attribute 'count'
