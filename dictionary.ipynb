# %%
d2={'ram':25,'shyam':35,'ronaldo':40}
d2
type(d2)
# Out:
# dict

# %%
d2={'even':[2,4,6],'odd':[3,5,7]}
d2
# Out:
# {'even': [2, 4, 6], 'odd': [3, 5, 7]}

# %%
d2={(2,4,6):'even',(3,5,7):'odd'}
d2
# Out:
# {(2, 4, 6): 'even', (3, 5, 7): 'odd'}

# %%
d1={1:2,2:3}
sum(d1)
# Out:
# 3

# %%
d1={'Ronaldo':40,'Ronsi':38,'Ronmmar':32}
max(d1)
for i in d1:
    print(i)
# Out:
# Ronaldo
# Ronsi
# Ronmmar

# %%
#WAP TO CREATE YOUR OWN DATABASE: empty dictionary

d1={}
d1['name']='sudip'
d1['age']='20'
d1['sex']='male'
d1
# Out:
# {'name': 'sudip', 'age': '20', 'sex': 'male'}

# %%
#Wap to create a dictionary based on two lists.
#names=['Ram','Raheem','Robert']
#age=[23,30,35]
names=['Ram','Raheem','Robert']
age=[23,30,35]
d1={}
for i,j in zip(names,age):
    d1[i]=j
d1
# Out:
# {'Ram': 23, 'Raheem': 30, 'Robert': 35}

# %%
#using range method
names=['Ram','Raheem','Robert']
age=[23,30,35]
d1={}
for i in range(len(names)):
    d1[names[i]]=age[i]
d1
# Out:
# {'Ram': 23, 'Raheem': 30, 'Robert': 35}

# %%
d1={}
even=[]
odd=[]
import random
for i in range(5):
    num=random.randint(1,30)
    if num%2==0:
        even.append(num)
    else:
        odd.append(num)
print(even)
print(odd)
d1={'even':even,'odd':odd}
print(d1)
# Out:
# [28, 8, 14]
# [29, 15]
# {'even': [28, 8, 14], 'odd': [29, 15]}

# %%
import random

d1 = {k: [n for n in (random.randint(1, 30) for _ in range(5)) if (n % 2 == 0) == (k == 'even')] for k in ('even', 'odd')}

print(d1)
