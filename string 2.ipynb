# %%
string1="python"
for i in range(6):
    print("the postive index is {} and negative index is {} for letter {}".format(i,i-6,string1[i]))
# Out:
# the postive index is 0 and negative index is -6 for letter p
# the postive index is 1 and negative index is -5 for letter y
# the postive index is 2 and negative index is -4 for letter t
# the postive index is 3 and negative index is -3 for letter h
# the postive index is 4 and negative index is -2 for letter o
# the postive index is 5 and negative index is -1 for letter n

# %%
string2="hello"
i=0
while i<=len(string2):
    print("the positive index of letter {} is {} and the negative index is {}".format(string2[i],i,i-6))
    i=i+1
# Out:
# the positive index of letter h is 0 and the negative index is -6
# the positive index of letter e is 1 and the negative index is -5
# the positive index of letter l is 2 and the negative index is -4
# the positive index of letter l is 3 and the negative index is -3
# the positive index of letter o is 4 and the negative index is -2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 4
#       2 i=0
#       3 while i<=len(string2):
# ----> 4     print("the positive index of letter {} is {} and the negative index is {}".format(string2[i],i,i-6))
#       5     i=i+1
#
# IndexError: string index out of range

# %%
string1="hai how are you"
count=0
for i in range(len(string1)):
    if string1[i]=="a":
        count=count+1
print(count)
# Out:
# 2

# %%
import string
dir(string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
string3="hai how are you"
string3[-2:-14:2]
# Out:
# ''

# %%
string1='welcome'
dir(string1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
string1='broTher'
string1.lower()
# Out:
# 'brother'

# %%
string1="hai how are you"
string1.count("a")
# Out:
# 2

# %%
string1="welcome"
str1=string1[:2]
str2=string1[3:]
string3=str1+"L"+str2
